# %%
import requests
import json

# 요청 헤더 설정 (웹사이트에서 차단되지 않도록 user-agent 추가)
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36'
}

class CardCrawler:
    def __init__(self, card_type):
        """
        CardCrawler 클래스 초기화
        :param card_type: 카드 타입 (CRD: 신용카드, CHK: 체크카드)
        """
        self.card_type = card_type  # 카드 타입 저장
        self.page_num = 1  # 크롤링할 페이지 번호 초기화
        self.cards_data = []  # 크롤링된 카드 정보를 저장할 리스트

    def get_card_data(self):
        """
        카드탭 페이지를 API로부터 받아오는 함수
        :return: 카드 기본 정보를 JSON 데이터로 반환 (요청 실패 시 None 반환)
        """
        url = f'https://api.card-gorilla.com:8080/v1/cards?p={self.page_num}&perPage=10&cate={self.card_type}'
        response = requests.get(url, headers=headers)
        
        if response.status_code == 200:
            return response.json()  # JSON 데이터를 반환
        else:
            print(f"Page {self.page_num} 요청 실패! 상태 코드: {response.status_code}")
            return None  # 요청 실패 시 None 반환

    def print_card_details(self, card):
        """
        카드의 세부 정보를 출력하는 함수
        :param card: 개별 카드 정보 (딕셔너리 형태)
        :return: 카드별 API URL 반환 (없을 경우 None)
        """
        if card.get('is_discon', False):  # 카드가 단종된 경우 출력하지 않고 건너뜀
            print(f"  카드 '{card.get('name')}'은(는) 사용 불가 카드입니다. 건너뜁니다.")
            return None
        
        # 카드 기본 정보 출력
        card_name = card.get('name', '이름 없음')
        card_idx = card.get('idx')  # 카드의 고유 인덱스
        card_cate_txt = card.get('cate_txt', '카테고리 없음')
        card_corp_txt = card.get('corp_txt', '발급사 없음')
        
        print(f"  카드 이름: {card_name}")
        print(f"    카드 카테고리: {card_cate_txt}")
        print(f"    카드 발급사: {card_corp_txt}")
        
        if card_idx:
            # 카드 상세 정보 API URL 및 웹페이지 URL 생성
            card_detail_api_url = f"https://api.card-gorilla.com:8080/v1/cards/{card_idx}" 
            card_detail_page_url = f"https://www.card-gorilla.com/card/detail/{card_idx}"
            
            print(f"    카드 상세 API URL: {card_detail_api_url}")
            print(f"    카드 상세 페이지 URL: {card_detail_page_url}")
            
            return card_detail_api_url  # 카드 상세 API URL 반환
        return None

    def get_card_detail(self, card_detail_url):
        """
        카드의 세부 정보를 받아오는 함수
        :param card_detail_url: 카드 상세 정보 API URL
        :return: 카드 상세 정보 JSON 데이터 반환 (요청 실패 시 None 반환)
        """
        response = requests.get(card_detail_url, headers=headers)
        
        if response.status_code == 200:
            return response.json()  # 카드 상세 정보를를 JSON 데이터로로 반환
        else:
            print(f"    카드 상세 정보 요청 실패! 상태 코드: {response.status_code}")
            return None

    def print_benefits(self, key_benefit):
        """
        카드 혜택을 출력하는 함수
        :param key_benefit: 카드 혜택 리스트
        :return: 카드 혜택 목록 반환 (없을 경우 기본 메시지 반환)
        """
        comments = [item['comment'] for item in key_benefit[:-1]]  # 마지막 항목 제외
        return comments if comments else ["혜택 정보가 없습니다."]

    def crawl_cards(self):
        """
        카드 크롤링을 수행하는 메인 함수
        """
        while True:
            json_data = self.get_card_data()  # get_card_data()함수를 호출하여여 카드탭 API에서 카드 데이터 요청
            
            if json_data:
                data_list = json_data.get('data', [])  # 기본 카드 데이터 리스트 추출
                
                if data_list:
                    print(f"\nPage {self.page_num}:") # 현재 페이지 출력
                    for card in data_list:
                        card_detail_url = self.print_card_details(card)  # print_card_details를 활용해 카드별 api 추출하여 저장
                        
                        if card_detail_url:  # 사용 가능한 카드만 처리
                            card_data = self.get_card_detail(card_detail_url) # get_card_detail을 활용하여 카드별별 api를 json 형태로 추출하여 저장
                            
                            if card_data: # card_data가 None이 아니라면 (즉, API 요청이 성공했다면), 아래의 코드를 실행
                                key_benefit = card_data.get('key_benefit', [])  # 카드 상세 정보에서 'key_benefit' 필드를 가져옴 (없으면 빈 리스트 반환)
                                benefits = self.print_benefits(key_benefit) # 가져온 혜택 정보를 정리하는 print_benefits 함수 호출
                                
                                # 카드 정보를 딕셔너리 형태로 정리하여 저장
                                card_idx = card.get('idx')
                                card_page_url = f"https://www.card-gorilla.com/card/detail/{card_idx}" if card_idx else "URL 없음"
                                card_info = {
                                    'name': card.get('name', '이름 없음'),
                                    'cate_txt': card.get('cate_txt', '카테고리 없음'),
                                    'corp_txt': card.get('corp_txt', '발급사 없음'),
                                    'benefits': benefits,
                                    'page_url': card_page_url
                                }
                                self.cards_data.append(card_info)
                    
                    self.page_num += 1  # 다음 페이지로 이동
                else:
                    print(f"더 이상 카드 정보가 없습니다. 크롤링을 종료합니다.")
                    break
            else:
                break  # 요청 실패 시 종료

        # 크롤링이 끝난 후 JSON 파일로 저장
        self.save_to_json()

    def save_to_json(self):
        """
        크롤링된 카드 정보를 JSON 파일로 저장하는 함수
        """
        with open(f'{self.card_type}_cards_data.json', 'w', encoding='utf-8') as json_file:
            json.dump(self.cards_data, json_file, ensure_ascii=False, indent=4)
        print(f"{self.card_type}_cards_data.json 파일로 저장되었습니다.")


# 이 파일이 직접 실행될 때만 아래 코드를 실행하도록 설정
# 다른 파일에서 이 파일을 임포트하면 아래 코드는 실행되지 않음
if __name__ == "__main__":
    # 사용자에게 카드 타입 입력 받기
    card_type = input("신용카드 (CRD) 또는 체크카드 (CHK)를 선택하세요: ").strip().upper()
    
    if card_type not in ['CRD', 'CHK']:
        print("잘못된 카드 타입입니다. 'CRD' 또는 'CHK'를 입력하세요.")
    else:
        card_crawler = CardCrawler(card_type)  # CardCrawler 객체 생성
        card_crawler.crawl_cards()  # 카드 크롤링 시작
# Out:
# Page 1:
#   카드 이름: 신한카드 Mr.Life
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/13
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/13
#   카드 이름: 삼성카드 taptap O
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/51
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/51
#   카드 이름: 삼성카드 & MILEAGE PLATINUM (스카이패스)
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/49
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/49
#   카드 이름: 현대카드 M
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2669
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2669
#   카드 이름: KB국민 My WE:SH 카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2441
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2441
#   카드 이름: LOCA LIKIT 1.2
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2261
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2261
#   카드 이름: 카드의정석 EVERY MILE SKYPASS
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2553
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2553
#   카드 이름: LOCA 365 카드
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2330
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2330
#   카드 이름: 신한카드 처음(ANNIVERSE)
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2759
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2759
#   카드 이름: 현대카드ZERO Edition3(할인형)
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2646
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2646
#
# Page 2:
#   카드 이름: 신한카드 Deep Oil
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/39
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/39
#   카드 이름: 삼성 iD SIMPLE 카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2376
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2376
#   카드 이름: 올바른 FLEX 카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/666
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/666
#   카드 이름: JADE Classic
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2657
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2657
#   카드 이름: BC 바로 클리어 플러스
#     카드 카테고리: 신용
#     카드 발급사: BC 바로카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2346
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2346
#   카드 이름: 현대카드 Summit
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2692
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2692
#   카드 이름: 하나 스카이패스 아멕스 플래티늄 카드
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2237
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2237
#   카드 이름: Easy all 티타늄카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/634
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/634
#   카드 이름: DA카드의정석Ⅱ
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2655
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2655
#   카드 이름: 디지로카 London
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2632
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2632
#
# Page 3:
#   카드 이름: 신한카드 The BEST-F
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/37
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/37
#   카드 이름: American Express® Green Card Edition2
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2662
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2662
#   카드 이름: 삼성 iD GLOBAL 카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2676
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2676
#   카드 이름: 현대카드 MX Black Edition2
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2697
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2697
#   카드 이름: American Express Blue
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/45
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/45
#   카드 이름: 굿데이올림카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/115
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/115
#   카드 이름: 카드의정석 EVERY DISCOUNT
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2719
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2719
#   카드 이름: IBK포인트(신용)
#     카드 카테고리: 신용
#     카드 발급사: IBK기업은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2779
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2779
#   카드 이름: 카드의정석 SHOPPING+
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2687
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2687
#   카드 이름: 아시아나 신한카드 Air 1.5
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/27
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/27
#
# Page 4:
#   카드 이름: BC 바로 On&Off 카드
#     카드 카테고리: 신용
#     카드 발급사: BC 바로카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2591
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2591
#   카드 이름: BeV V카드(스카이패스형)
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/131
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/131
#   카드 이름: 다담카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/121
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/121
#   카드 이름: 대한항공카드 300
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2711
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2711
#   카드 이름: CLUB SK 카드
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/227
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/227
#   카드 이름: American Express® Gold Card Edition2
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2663
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2663
#   카드 이름: 신한카드 Air One
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/466
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/466
#   카드 이름: LOCA Professional
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2636
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2636
#   카드 이름: 신한카드 RPM+ Platinum#
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/16
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/16
#   카드 이름: 삼성 iD ALL 카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2234
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2234
#
# Page 5:
#   카드 이름: The Easy카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/146
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/146
#   카드 이름: K-패스 (신용)
#     카드 카테고리: 신용
#     카드 발급사: IBK기업은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2559
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2559
#   카드 이름: zgm.the pay카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2427
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2427
#   카드 이름: 현대카드ZERO Edition3(포인트형)
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2647
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2647
#   카드 이름: 신한카드 Point Plan
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2666
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2666
#   카드 이름: I-Mileage (대한항공)
#     카드 카테고리: 신용
#     카드 발급사: IBK기업은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2674
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2674
#   카드 이름: K-패스 신한카드
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2690
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2690
#   카드 이름: BC 바로 MACAO 카드
#     카드 카테고리: 신용
#     카드 발급사: BC 바로카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2728
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2728
#   카드 이름: ALL 우리카드 Infinite
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2613
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2613
#   카드 이름: 현대카드Z family Edition2
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2683
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2683
#
# Page 6:
#   카드 이름: 올바른 NEW HAVE카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/635
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/635
#   카드 이름: 원더카드 (원더 Life)
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2654
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2654
#   카드 이름: 삼성 iD ON 카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2235
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2235
#   카드 이름: JADE Prime
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2703
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2703
#   카드 이름: 디지로카 Las Vegas
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2707
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2707
#   카드 이름: THE iD. PLATINUM(포인트)
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2460
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2460
#   카드 이름: BLISS.5 카드(마일리지)
#     카드 카테고리: 신용
#     카드 발급사: IBK기업은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/772
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/772
#   카드 이름: the Green Edition3
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2753
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2753
#   카드 이름: 네이버 현대카드 Edition2
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2794
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2794
#   카드 이름: the Red (항공 마일리지형)
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2737
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2737
#
# Page 7:
#   카드 이름: 신한카드 처음
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2694
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2694
#   카드 이름: 신한카드 Edu Plan+
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2735
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2735
#   카드 이름: SKYPASS 롯데 아멕스카드
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/432
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/432
#   카드 이름: IBK포인트3.8(신용)
#     카드 카테고리: 신용
#     카드 발급사: IBK기업은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2778
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2778
#   카드 이름: Oil & Life카드(Oil카드)
#     카드 카테고리: 신용
#     카드 발급사: IBK기업은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/258
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/258
#   카드 이름: LOCA LIKIT Eat
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2262
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2262
#   카드 이름: 네이버페이 taptap
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/458
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/458
#   카드 이름: 쿠팡 와우 카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2609
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2609
#   카드 이름: taptap DIGITAL
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/657
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/657
#   카드 이름: GOAT BC 바로카드
#     카드 카테고리: 신용
#     카드 발급사: BC 바로카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2644
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2644
#
# Page 8:
#   카드 이름: 올바른 MYPICK 카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/654
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/654
#   카드 이름: 티머니 Pay & GO 신한카드
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2386
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2386
#   카드 이름: 트래블월렛 우리카드
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2569
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2569
#   카드 이름: 국민행복 삼성카드 V2
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/718
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/718
#   카드 이름: 토스뱅크 하나카드 Wide
#     카드 카테고리: 신용
#     카드 발급사: 토스뱅크
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2732
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2732
#   카드 이름: 하나 CLUB H 아메리칸 익스프레스 리저브 카드
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2406
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2406
#   카드 이름: HERITAGE Smart [대한항공 마일리지형]
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2451
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2451
#   카드 이름: 신한카드 국민행복
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/712
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/712
#   카드 이름: K-22(Mileage)
#     카드 카테고리: 신용
#     카드 발급사: IBK기업은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2536
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2536
#   카드 이름: 가온올림카드(실속형)
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/769
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/769
#
# Page 9:
#   카드 이름: BeV V카드(포인트형)
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/130
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/130
#   카드 이름: 현대백화점카드
#     카드 카테고리: 신용
#     카드 발급사: 현대백화점
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2344
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2344
#   카드 이름: 청춘대로 톡톡카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/129
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/129
#   카드 이름: the Pink Edition2
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2752
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2752
#   카드 이름: zgm.일본여행중 카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2593
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2593
#   카드 이름: zgm 할인카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2706
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2706
#   카드 이름: 삼성 iD ENERGY 카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2290
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2290
#   카드 이름: 신한카드 Deep On Platinum+
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/41
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/41
#   카드 이름: BC 바로 리워드 플러스
#     카드 카테고리: 신용
#     카드 발급사: BC 바로카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2347
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2347
#   카드 이름: JADE First Centum
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2705
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2705
#
# Page 10:
#   카드 이름: THE iD. TITANIUM(포인트)
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2461
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2461
#   카드 이름: zgm.play카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2544
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2544
#   카드 이름: zgm.휴가중카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2464
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2464
#   카드 이름: 신한카드 The CLASSIC+
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/15
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/15
#   카드 이름: 신한카드 구독 좋아요
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2453
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2453
#   카드 이름: 원더카드 FREE
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2446
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2446
#   카드 이름: 롯데백화점 롯데카드
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/201
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/201
#   카드 이름: 대한항공카드 120
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2710
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2710
#   카드 이름: 신한카드 Point Plan+
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2731
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2731
#   카드 이름: 신세계이마트 삼성카드7
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/64
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/64
#
# Page 11:
#   카드 이름: 트래블로그 신용카드
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2529
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2529
#   카드 이름: taptap DRIVE
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/658
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/658
#   카드 이름: 모니모카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2349
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2349
#   카드 이름: NH올원 파이카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/181
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/181
#   카드 이름: #Pay 신한카드
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2258
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2258
#   카드 이름: 별다줄카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2305
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2305
#   카드 이름: ALL 우리카드 Premium
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2612
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2612
#   카드 이름: 始發(시발)카드
#     카드 카테고리: 신용
#     카드 발급사: BC 바로카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2418
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2418
#   카드 이름: 메리어트 본보이™ 더 베스트 신한카드
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/716
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/716
#   카드 이름: BeV Ⅲ 카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/133
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/133
#
# Page 12:
#   카드 이름: 로얄블루1000카드 [SKYPASS]
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/1731
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/1731
#   카드 이름: 삼성카드 taptap I
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/59
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/59
#   카드 이름: Easy pick 티타늄 카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/580
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/580
#   카드 이름: 삼성 iD VITA 카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2534
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2534
#   카드 이름: HERITAGE Classic [스카이패스형]
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2781
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2781
#   카드 이름: Mile1 하나카드
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2572
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2572
#   카드 이름: 대한항공카드 the First Edition2
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2712
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2712
#   카드 이름: 디지로카 Edu
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2714
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2714
#   카드 이름: 삼성 iD CLASSY 카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2702
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2702
#   카드 이름: IBK무민카드(신용)
#     카드 카테고리: 신용
#     카드 발급사: IBK기업은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/723
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/723
#
# Page 13:
#   카드 이름: 디지로카 Auto
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2717
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2717
#   카드 이름: the black
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2757
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2757
#   카드 이름: 신한카드 The CLASSIC-Y
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/8
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/8
#   카드 이름: 현대카드 MM
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2670
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2670
#   카드 이름: 현대백화점 Fit카드
#     카드 카테고리: 신용
#     카드 발급사: 현대백화점
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2345
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2345
#   카드 이름: 현대카드Z work Edition2
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2680
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2680
#   카드 이름: zgm shopping카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2648
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2648
#   카드 이름: 카드의정석 TEN
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2699
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2699
#   카드 이름: 대한항공카드 060
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2709
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2709
#   카드 이름: K-패스 카드
#     카드 카테고리: 신용
#     카드 발급사: BC 바로카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2557
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2557
#
# Page 14:
#   카드 이름: 카카오뱅크 개인사업자 삼성카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2420
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2420
#   카드 이름: 신협-신한카드 Hi-Point
#     카드 카테고리: 신용
#     카드 발급사: 신협
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/1584
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/1584
#   카드 이름: American Express The Platinum Card®Edition2
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2664
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2664
#   카드 이름: 카드의정석 EVERY POINT
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2689
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2689
#   카드 이름: 스카이패스 티타늄 카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2327
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2327
#   카드 이름: 디지로카 Paris
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2633
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2633
#   카드 이름: 카드의정석 PREMIUM MILEAGE(SKYPASS)
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/92
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/92
#   카드 이름: 넥슨 현대카드UNLIMITED
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2388
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2388
#   카드 이름: 네이버페이 라인프렌즈 신한카드
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/651
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/651
#   카드 이름: K-패스카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2555
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2555
#
# Page 15:
#   카드 이름: 삼성 BIZ iD BENEFIT카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2324
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2324
#   카드 이름: 스카이패스 삼성아멕스카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/61
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/61
#   카드 이름: 신한카드 Air Platinum#
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/12
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/12
#   카드 이름: WE:SH Travel
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2685
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2685
#   카드 이름: LOCA LIKIT Play
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2263
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2263
#   카드 이름: 쇼핑앤조이 카드
#     카드 카테고리: 신용
#     카드 발급사: IBK기업은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/274
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/274
#   카드 이름: 국민행복카드(신용)
#     카드 카테고리: 신용
#     카드 발급사: IBK기업은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/260
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/260
#   카드 이름: 금융포인트리카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/578
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/578
#   카드 이름: 네이버페이 신한카드
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/577
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/577
#   카드 이름: 신한카드 LABE
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/1006
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/1006
#
# Page 16:
#   카드 이름: 제주항공 Refresh Point 카드
#     카드 카테고리: 신용
#     카드 발급사: IBK기업은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/275
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/275
#   카드 이름: Easy all 카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/630
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/630
#   카드 이름: K-패스 삼성카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2558
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2558
#   카드 이름: MY S-OIL 삼성카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2539
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2539
#   카드 이름: 삼성카드 BIZ LEADERS
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/780
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/780
#   카드 이름: IBK-Hybrid(하이브리드)카드
#     카드 카테고리: 신용
#     카드 발급사: IBK기업은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/269
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/269
#   카드 이름: D4카드의정석Ⅱ
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2686
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2686
#   카드 이름: New후불하이패스카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/1577
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/1577
#   카드 이름: 네이버페이 쇼핑엔로카
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2433
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2433
#   카드 이름: I-Mileage (아시아나)
#     카드 카테고리: 신용
#     카드 발급사: IBK기업은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2675
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2675
#
# Page 17:
#   카드 이름: 카드의정석 MILEAGE SKYPASS
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/548
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/548
#   카드 이름: 현대카드 X
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2679
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2679
#   카드 이름: 싱가포르항공 크리스플라이어 더 베스트 신한카드
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2592
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2592
#   카드 이름: LOCA LIKIT Shop
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2264
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2264
#   카드 이름: BC 바로 기후동행카드
#     카드 카테고리: 신용
#     카드 발급사: BC 바로카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2774
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2774
#   카드 이름: 카드의정석 EVERY 1
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2551
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2551
#   카드 이름: 신한카드 The PREMIER GOLD EDITION (스카이패스)
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2090
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2090
#   카드 이름: KB국민 WE:SH All카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2440
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2440
#   카드 이름: 삼성 iD PLUG-IN 카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2661
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2661
#   카드 이름: 신한카드 후불하이패스+ (하이패스 전용)
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/884
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/884
#
# Page 18:
#   카드 이름: 탄탄대로 Biz 카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/697
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/697
#   카드 이름: Oil & Life카드(Life카드)
#     카드 카테고리: 신용
#     카드 발급사: IBK기업은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/259
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/259
#   카드 이름: 모니모A
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2631
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2631
#   카드 이름: Easy ring 티타늄카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/615
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/615
#   카드 이름: 카드의정석 I&U+
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2688
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2688
#   카드 이름: 토스 신용카드
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/589
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/589
#   카드 이름: 신한카드 SOL트래블
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2722
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2722
#   카드 이름: #tag1카드 Navy
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/248
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/248
#   카드 이름: SKT 우리카드
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/1555
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/1555
#   카드 이름: 하나 원큐 카드
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/1174
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/1174
#
# Page 19:
#   카드 이름: SSG.COM 삼성카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/681
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/681
#   카드 이름: 알뜰폰 Hub Ⅱ 카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/727
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/727
#   카드 이름: 가온글로벌카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/1309
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/1309
#   카드 이름: Diners Club POINT
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2396
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2396
#   카드 이름: K-패스카드(신용)
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2560
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2560
#   카드 이름: NH20 해봄카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/184
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/184
#   카드 이름: taptap SHOPPING
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/659
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/659
#   카드 이름: 카드의정석 UNTACT AIR
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/661
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/661
#   카드 이름: 1Q Special+
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/241
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/241
#   카드 이름: CLUB1카드 200
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2091
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2091
#
# Page 20:
#   카드 이름: 굿데이카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/106
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/106
#   카드 이름: 기후동행 삼성카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2771
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2771
#   카드 이름: 신한카드 Deep Once
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/536
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/536
#   카드 이름: 신한카드 집
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/889
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/889
#   카드 이름: LOCA 나누기 카드
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2395
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2395
#   카드 이름: 신한카드 Deep Making
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/476
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/476
#   카드 이름: 일상의 기쁨카드(신용)
#     카드 카테고리: 신용
#     카드 발급사: IBK기업은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/266
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/266
#   카드 이름: 카드의정석 APT
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/543
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/543
#   카드 이름: American Express Blue KB Kookmin Card
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2624
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2624
#   카드 이름: KB국민 Our WE:SH 카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2442
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2442
#
# Page 21:
#   카드 이름: 카카오뱅크 KB국민카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/591
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/591
#   카드 이름: 트레이더스신세계 삼성카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/72
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/72
#   카드 이름: CEO카드
#     카드 카테고리: 신용
#     카드 발급사: IBK기업은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2339
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2339
#   카드 이름: 신세계 BC 바로 콰트로 플러스
#     카드 카테고리: 신용
#     카드 발급사: BC 바로카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2380
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2380
#   카드 이름: BLISS.5 카드(포인트)
#     카드 카테고리: 신용
#     카드 발급사: IBK기업은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/773
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/773
#   카드 이름: Easy shopping 티타늄카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/912
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/912
#   카드 이름: OK캐쉬백 위비할인카드
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/1859
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/1859
#   카드 이름: 신한카드 YOLO ⓘ
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/14
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/14
#   카드 이름: 트래블로그 SKYPASS 신용카드
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2729
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2729
#   카드 이름: American Express® Reserve
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/736
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/736
#
# Page 22:
#   카드 이름: SmileCard Edition2
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/852
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/852
#   카드 이름: 마일리지 가온카드(대한항공)
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/113
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/113
#   카드 이름: Kia Members 신용카드 Edition2
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2195
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2195
#   카드 이름: NH올원 All100(올백)카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/177
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/177
#   카드 이름: zgm.streaming카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2428
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2428
#   카드 이름: 카카오뱅크 삼성카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/592
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/592
#   카드 이름: K-패스 하나 신용카드
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2681
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2681
#   카드 이름: 삼성카드 taptap S
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/52
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/52
#   카드 이름: 신한카드 Deep Taking
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/477
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/477
#   카드 이름: 신한카드 EVerywhere
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2435
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2435
#
# Page 23:
#   카드 이름: 트래블로그 PRESTIGE 신용카드
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2730
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2730
#   카드 이름: HERITAGE Classic [할인형]
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2780
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2780
#   카드 이름: HERITAGE Smart [할인형]
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2450
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2450
#   카드 이름: Kia Members 경차전용카드(유류세 환급)
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/859
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/859
#   카드 이름: RAUME O (스카이패스)
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/1865
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/1865
#   카드 이름: 기후동행카드(신용)
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2772
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2772
#   카드 이름: 신한카드 주거래 신용
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/895
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/895
#   카드 이름: 어디로든 그린카드 X LOCA
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2641
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2641
#   카드 이름: ZipL 신용카드
#     카드 카테고리: 신용
#     카드 발급사: BNK부산은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2645
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2645
#   카드 이름: 카카오페이 신용카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/764
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/764
#
# Page 24:
#   카드 이름: 후불하이패스 카드
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/1032
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/1032
#   카드 이름: Easy link 티타늄카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/551
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/551
#   카드 이름: 삼성페이 삼성카드 taptap
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/63
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/63
#   카드 이름: 삼성페이카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/662
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/662
#   카드 이름: 신한카드 Shopping
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/18
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/18
#   카드 이름: 신한카드 Simple Platinum#
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/21
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/21
#   카드 이름: 코스트코 리워드 현대카드 Edition2
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2640
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2640
#   카드 이름: 신한카드 Deep Store
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/43
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/43
#   카드 이름: 힐튼 아너스 아멕스 프리미엄
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2786
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2786
#   카드 이름: 디지로카 Monaco
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2634
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2634
#
# Page 25:
#   카드 이름: 신한카드 Cube Platinum#
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/36
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/36
#   카드 이름: 신한카드 Edu
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/26
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/26
#   카드 이름: 신한카드 The CLASSIC-L
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/33
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/33
#   카드 이름: 원더카드 LIVING
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2447
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2447
#   카드 이름: the Purple
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2756
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2756
#   카드 이름: 올바른 POINT UP 카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/512
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/512
#   카드 이름: 카드의정석 댕댕냥이(강아지)
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/481
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/481
#   카드 이름: SKT-현대카드M Edition3(라이트할부형2.0)
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2472
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2472
#   카드 이름: 메리어트 본보이™ 더 클래식 신한카드
#     카드 카테고리: 신용
#     카드 발급사: 신한카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2291
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2291
#   카드 이름: BC 바로 KaPick
#     카드 카테고리: 신용
#     카드 발급사: BC 바로카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2724
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2724
#
# Page 26:
#   카드 이름: JADE First
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2704
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2704
#   카드 이름: the Red Stripe Edition2
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2755
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2755
#   카드 이름: 삼성 iD ONE 카드
#     카드 카테고리: 신용
#     카드 발급사: 삼성카드
# ...
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/1695
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/1695
#   카드 이름: 현대홈쇼핑 현대카드
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2736
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2736
#   카드 이름: [광주] K-그린카드v2
#     카드 카테고리: 신용
#     카드 발급사: 광주은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2564
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2564
#   카드 이름: #ing(샵핑)카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/162
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/162
#   카드 이름: #ing+(샵핑플러스)카드
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/163
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/163
#   카드 이름: 1st 플래티늄 카드
#     카드 카테고리: 신용
#     카드 발급사: 전북은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2181
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2181
#   카드 이름: AK KB국민카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/942
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/942
#   카드 이름: BNK 프렌즈 신용카드
#     카드 카테고리: 신용
#     카드 발급사: BNK부산은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/1209
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/1209
#
# Page 76:
#   카드 이름: GS SHOP KB국민카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/778
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/778
#   카드 이름: GS&POINT 롯데카드
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2005
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2005
#   카드 이름: Happy 디지털카드
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2369
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2369
#   카드 이름: LFmall 신용카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2486
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2486
#   카드 이름: LOCA for Auto
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/621
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/621
#   카드 이름: LOCA for 롯데마트
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2537
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2537
#   카드 이름: LOCA in MEGACITY
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2360
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2360
#   카드 이름: 갤러리아 KB국민카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2434
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2434
#   카드 이름: 넥센타이어 KB국민카드
#     카드 카테고리: 신용
#     카드 발급사: KB국민카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/1380
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/1380
#   카드 이름: 뉴GS칼텍스 롯데카드
#     카드 카테고리: 신용
#     카드 발급사: 롯데카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/1754
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/1754
#
# Page 77:
#   카드 이름: 닥터구디 T&R(티앤알) 카드
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2365
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2365
#   카드 이름: 부자되세요 HomeShopping카드(비씨)
#     카드 카테고리: 신용
#     카드 발급사: NH농협카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/176
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/176
#   카드 이름: 산림조합-현대카드M(청구할인형)
#     카드 카테고리: 신용
#     카드 발급사: 현대카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2199
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2199
#   카드 이름: 셀리턴 우리카드
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/596
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/596
#   카드 이름: 올레 Super DC 대구은행카드
#     카드 카테고리: 신용
#     카드 발급사: iM뱅크
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/838
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/838
#   카드 이름: 이디야 하나카드
#     카드 카테고리: 신용
#     카드 발급사: 하나카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2466
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2466
#   카드 이름: 제주 삼다수카드(신용)
#     카드 카테고리: 신용
#     카드 발급사: 제주은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2132
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2132
#   카드 이름: 제주그린카드
#     카드 카테고리: 신용
#     카드 발급사: 제주은행
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/2151
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/2151
#   카드 이름: 카드의정석 삼성디지털프라자
#     카드 카테고리: 신용
#     카드 발급사: 우리카드
#     카드 상세 API URL: https://api.card-gorilla.com:8080/v1/cards/594
#     카드 상세 페이지 URL: https://www.card-gorilla.com/card/detail/594
#   카드 '#any 하나카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 78:
#   카드 '1Q Daily+'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '1Q Daily+[40주년 에디션]'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '1Q Global VIVA'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '1Q Living+'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '1Q My Lunch'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '1Q Shopping+'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'AK우리카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'AK우리카드 VIP'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'ALL MY DC'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'ALL MY DRIVING'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 79:
#   카드 'ALL MY LIVING'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'ALL MY POINT'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'ALL 다모아카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'American Express The Platinum Card®'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'American Express® Gold Card'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'American Express® Green Card'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'BAZIC(베이직)카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'BAZIC+(베이직플러스)카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'BC 바로 에어 플러스 스카이패스'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'BC 바로 페이백 플러스'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 80:
#   카드 'BLISS.7 카드(마일리지)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'BLISS.7 카드(포인트)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'CJ ONE 삼성카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'Clip카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'D4@카드의정석'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'DA@카드의정석'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'Diners Club MILEAGE'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'Easy study 티타늄카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'EDIYA 신한카드 Tasty'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'Hole In:WON(홀인원) 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 81:
#   카드 'I’m ACTIVE'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'I’m CHEERFUL'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'I’m DRIVING'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'I’m GREAT'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'I’m JOYFUL'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'I’m Powerful'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'I’m WONDERFUL platinum'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'I’m Wonderful Plus'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'IBK DC히어로즈 카드(신용)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'IBK 무직타이거 카드(신용)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 82:
#   카드 'K-FIRST (모바일전용)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'KB국민 윙크카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'KT NU우리카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'L.CLASS L60 (L.POINT형)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'L.CLASS L60 (스카이패스형)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'L.CLASS L60 (아시아나클럽형)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'L.PAY by 롤라카드(신용)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'LG U+ 우리카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'LGU+ 카드의정석 Ⅱ'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'LG전자 라서즐거운 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 83:
#   카드 'LG전자 렌탈 플러스 하나카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'LG전자 베스트렌탈 우리카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'LoL CHAMPIONS KOREA 우리카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'Mile 1.8 대한항공'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'Mile 1.8 아시아나'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'Mobile x LOCA 롯데카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'my pass 마패 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'NEW 씨티 클리어'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'New 제주항공 하나카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'NH올원 Shopping&11번가카드(R2타입)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 84:
#   카드 'NH올원 하나로카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'NH올원카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'NU Blanc'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'NU I&U'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'NU Uniq'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'NU Uniq point'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'ONE AIR(UniMile)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'ONE카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'ONLY 나만의카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'Paydays 신한카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 85:
#   카드 'Smart Any 카드(스마트애니)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'T-Premium KB국민카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'the Green'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'the Green Edition2'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'the Pink'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'the Purple Edition2'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'the Purple osée'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'the Red Edition3'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'the Red Edition4'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'the Red Edition5'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 86:
#   카드 'the Red Stripe'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 'WON DISCOUNT(원 디스카운트) AIR'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '골프존 KB국민카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '그랑블루 1st'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '내맘대로 쁨 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '네이버 현대카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '네이버페이 플래티넘 롯데카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '뉴타임카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '대한항공카드 030'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '대한항공카드 070'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 87:
#   카드 '대한항공카드 150'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '대한항공카드 the First'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '롭스 롯데카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '롯데홈쇼핑 벨리곰 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '마일앤조이카드(대한항공)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '마일앤조이카드(아시아나)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '만나 우리카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '모두의 건강'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '모두의 쇼핑'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '모바일 Tmoney 신한카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 88:
#   카드 '몰테일 KB국민카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '바디프랜드 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '배민현대카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '밸런스 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '블랙핑크 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '삼성 iD EDU 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '삼성 iD EV 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '삼성카드 애니패스+'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '삼성카드 지엔미+'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '샤롯데 비앤 롯데카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 89:
#   카드 '샤롯데 플래티넘 스타 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '소노시즌 하나카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '슈퍼쇼퍼카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '스카이패스카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '시그마카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신세계 씨티 클리어 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 23.5°'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 All Pass'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 Always FAN'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 Cube'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 90:
#   카드 '신한카드 D-day'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 Deep Dream'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 Deep Dream Platinum+'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 Deep Dream(모베러웍스)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 Deep ECO'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 Eats More(곰표)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 Hi-Point'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 Lady'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 Love'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 Noon'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 91:
#   카드 '신한카드 O2O'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 Puzzle'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 The LADY CLASSIC'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 The More(더모아)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 YOLO Tasty'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '신한카드 래플(Raffle)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '썸(SUM) 페이 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '씨티 NEW 캐시백'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '씨티 NEW 프리미어마일 대한항공'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '씨티 NEW 프리미어마일 아시아나'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 92:
#   카드 '씨티 리워드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '씨티 메가마일 스카이패스'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '씨티 메가마일 아시아나'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '씨티 프리미어마일 대한항공'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '씨티 프리미어마일 아시아나'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '아멕스 플래티넘 아시아나클럽 롯데카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '아모레퍼시픽 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '알뜰교통 my pass 마패 신용카드(Hana-BC)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '알뜰교통카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '알뜰폰 Hub 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 93:
#   카드 '엉 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '에너지플러스카드 Edition2'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '에듀카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '올마이쇼핑 카드 (교통)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '올마이쇼핑 카드 (점심)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '올마이쇼핑 카드 (통신)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '올마이쇼핑 카드 (해외)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '우리 K-패스(신용)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '우리 XGOLF 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '우리Most카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 94:
#   카드 '위메프 우리카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '위메프페이 신용카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '위비멤버스카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '이랜드리테일 롯데카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '인터파크 롯데카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '차이 신용카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '청춘대로 1코노미 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '청춘대로 꿀맛α카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '청춘대로 꿀잠α카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '청춘대로 꿀잼α카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 95:
#   카드 '청춘대로 매니아i카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '청춘대로카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카드의정석 Dear, Shopper(디어쇼퍼)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카드의정석 Dear, Traveler(디어트래블러)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카드의정석 DISCOUNT'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카드의정석 HEROES'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카드의정석 L.POINT'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카드의정석 MILEAGE Asiana Club'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카드의정석 NEW우리V카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카드의정석 POINT'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 96:
#   카드 '카드의정석 PREMIUM MILEAGE(AsianaClub)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카드의정석 PREMIUM POINT'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카드의정석 SHOPPING'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카드의정석 UniMile'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카드의정석 UNTACT'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카드의정석 WOWRI'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카드의정석 베트남여행'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카드의정석 삼성화재 당신에게 좋은보험'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카드의정석 위비온 플러스'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카라이프 삼성카드 DISCOUNT+'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 97:
#   카드 '카카오뱅크 신한카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카카오뱅크 씨티카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카카오뱅크 우리카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카카오뱅크 하나카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '카카오페이 신한카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '코스트코 리워드 비즈니스 현대카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '코스트코 리워드 현대카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '쿠팡 롯데카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '탄탄대로 온리유카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '톡톡 my living카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 98:
#   카드 '톡톡 my point카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '톡톡D 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '톡톡F 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '톡톡M 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '톡톡O 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '통커 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '펫 사랑 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '플러스마일카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '하나멤버스 1Q(원큐) 카드 Daily'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '하나멤버스 1Q(원큐) 카드 Living'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 99:
#   카드 '하나멤버스 1Q(원큐) 카드 Shopping'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '하나멤버스 1Q카드 내맘대로'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '하나투어 KB국민카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '한화손해보험 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '해피포인트 KB국민카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '해피포인트 해피리워드 카드'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '현대카드 DIGITAL LOVER'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '현대카드 M BOOST'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '현대카드 M2 BOOST'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '현대카드 M3 BOOST'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 100:
#   카드 '현대카드 MX Black'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '현대카드 X BOOST'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '현대카드 X2 BOOST'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '현대카드 X3 BOOST'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '현대카드Z family'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '현대카드Z ontact'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '현대카드Z work'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '현대카드ZERO Edition2(포인트형)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '현대카드ZERO Edition2(할인형)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '현대카드ZERO MOBILE Edition2(포인트형)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#
# Page 101:
#   카드 '현대카드ZERO MOBILE Edition2(할인형)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '현대카드ZERO MOBILE(포인트형)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '현대카드ZERO MOBILE(할인형)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '현대카드ZERO(포인트형)'은(는) 사용 불가 카드입니다. 건너뜁니다.
#   카드 '현대카드ZERO(할인형)'은(는) 사용 불가 카드입니다. 건너뜁니다.
# 더 이상 카드 정보가 없습니다. 크롤링을 종료합니다.
# CRD_cards_data.json 파일로 저장되었습니다.
