# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in c:\users\host\anaconda3\envs\study\lib\site-packages (1.61.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\host\anaconda3\envs\study\lib\site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\host\anaconda3\envs\study\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\host\anaconda3\envs\study\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\host\anaconda3\envs\study\lib\site-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\host\anaconda3\envs\study\lib\site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in c:\users\host\anaconda3\envs\study\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\host\anaconda3\envs\study\lib\site-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\host\anaconda3\envs\study\lib\site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in c:\users\host\anaconda3\envs\study\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in c:\users\host\anaconda3\envs\study\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\host\anaconda3\envs\study\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\host\anaconda3\envs\study\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\host\anaconda3\envs\study\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\host\anaconda3\envs\study\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: colorama in c:\users\host\anaconda3\envs\study\lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\host\anaconda3\envs\study\lib\site-packages (0.3.17)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\host\anaconda3\envs\study\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\host\anaconda3\envs\study\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\host\anaconda3\envs\study\lib\site-packages (from langchain) (3.10.5)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.33 in c:\users\host\anaconda3\envs\study\lib\site-packages (from langchain) (0.3.33)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\users\host\anaconda3\envs\study\lib\site-packages (from langchain) (0.3.5)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\host\anaconda3\envs\study\lib\site-packages (from langchain) (0.3.6)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\host\anaconda3\envs\study\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\host\anaconda3\envs\study\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\host\anaconda3\envs\study\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\host\anaconda3\envs\study\lib\site-packages (from langchain) (8.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\host\anaconda3\envs\study\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\host\anaconda3\envs\study\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\host\anaconda3\envs\study\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\host\anaconda3\envs\study\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\host\anaconda3\envs\study\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\host\anaconda3\envs\study\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.11.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\host\anaconda3\envs\study\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\host\anaconda3\envs\study\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\host\anaconda3\envs\study\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\host\anaconda3\envs\study\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\host\anaconda3\envs\study\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\host\anaconda3\envs\study\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\host\anaconda3\envs\study\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\host\anaconda3\envs\study\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\host\anaconda3\envs\study\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\host\anaconda3\envs\study\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\host\anaconda3\envs\study\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\host\anaconda3\envs\study\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\host\anaconda3\envs\study\lib\site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\host\anaconda3\envs\study\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: anyio in c:\users\host\anaconda3\envs\study\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\host\anaconda3\envs\study\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\host\anaconda3\envs\study\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\host\anaconda3\envs\study\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\host\anaconda3\envs\study\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.33->langchain) (2.1)

# %%
import os
import json
import numpy as np
import seaborn as sns
from tqdm import tqdm
from openai import OpenAI
from getpass import getpass

# %%
MY_API_KEY = getpass("OpenAI API Key: ")

# %%
# OpenAI API 클라이언트 객체 생성
client = OpenAI(api_key=MY_API_KEY)

# %%
# 페르소나 정의
persona1 = """
김형석 28세 남성
데이터 분석가를 꿈꾸는 취업준비생이다.
금융 도메인에 관심이 많다.
서울 거주중 부모님과 함께 산다.
수입은 파트 타임을 뛰면서 한달에 약 30~50만원에 정도 번다.
식사는 주로 집에서 해결한다.
차는 없고 대중교통을 주로 이용한다.
평소 카페에서 자격증 공부와 취업준비를 하고 있다.
취미는 클래식 음악 감상이다.
현재 불확실한 미래에 대해 고민이 많다.
"""

persona2 = """
이혜성 30세 여성
중견기업 입사 3년 차, 마케팅 부서 근무중이다.
서울 거주중이고 보증금 500만원 월세 50 만원의 방에서 자취한다. 
소득은 약 월 250~300만원 이다.
자차를 보유중이다.
취미로는 필라테스와 영화감상이 있다.
최근 주식 투자에 관심이 많다.
개인 일상 공유 블로그와 인스타그램을 운영중이다.
"""

persona3 = """
양호성 50세 남성
국내 1위 자동차기업에 다니며 직급은 부장이다.
지방광역시에 거주하며 40평 아파트와 고급 외제차 1대와 국산 중형 승용차 1대를 보유중이다.
수입은 약 월 900~1000만원 정도이다.
가부장적인 가장으로서 아내와 슬하에 딸 2명이 있다.
고민 사항으로 다가오는 정년퇴직과 점점 멀어지고 있는 자녀들과의 심리적 거리가 있다.
취미는 등산과 골프다.
비밀리에 맛집 공유 인스타그램을 운영중이며 20만 팔로워를 보유하고 있다.
"""

# 페르소나 리스트로 저장
personas = [persona1, persona2, persona3]

def recommend_card(persona):
    """
    OpenAI API를 사용하여 페르소나에 맞는 카드 추천을 요청하는 함수
    """
    prompt = f"""{persona}
             위 사람에게 맞는 최적의 신용 및 체크카드를 추천해주세요. 추천 이유도 함께 설명해주세요.
             """

    try:
        completion = client.chat.completions.create(
            model="gpt-3.5-turbo",  # gpt-3.5-turbo모델 사용 (필요시 최신 모델로 변경 가능)
            messages = [{'role':'user', 'content':prompt}],
            max_tokens=1000,  # 응답의 길이 조정
            temperature=0 # 창의성 조절 (0~1 사이 값)
        )
        return completion.choices[0].message.content
    
    except Exception as e:
        return f"API 호출 중 오류 발생: {e}"

# 각 페르소나에 대한 카드 추천 결과 출력
for i, persona in enumerate(personas, 1):
    print(f"\n--- 페르소나 {i} 추천 결과 ---")
    recommendation = recommend_card(persona)
    print(recommendation)
# Out:
# --- 페르소나 1 추천 결과 ---
# 김형석 씨에게는 현재 수입이 일정하지 않고 불확실한 미래에 대해 고민이 많은 상황이므로, 신용 및 체크카드를 선택할 때 안정적인 혜택과 혜택을 받을 수 있는 카드를 추천해드리겠습니다.
#
# 1. 체크카드: KB국민은행 비씨체크카드
# - KB국민은행의 비씨체크카드는 국내외 가맹점에서 현금처럼 사용할 수 있는 체크카드로, 현금이 부족한 상황에서도 편리하게 사용할 수 있습니다.
# - 또한, KB국민은행은 다양한 혜택을 제공하고 있어 김형석 씨가 일정하지 않은 수입을 보완할 수 있는 혜택을 받을 수 있습니다.
#
# 2. 신용카드: 삼성카드 The 삼성카드
# - 삼성카드는 다양한 혜택과 할인을 제공하여 일상 생활에서 부담을 덜어줄 수 있는 카드입니다.
# - 또한, 삼성카드는 김형석 씨가 자주 이용하는 카페나 음악 관련 이벤트 등 다양한 혜택을 제공하고 있어 취미를 즐기는 데 도움이 될 것입니다.
#
# 이처럼 KB국민은행의 비씨체크카드와 삼성카드 The 삼성카드를 추천드립니다. 현재 상황과 취향에 맞는 카드를 선택하여 안정적인 경제 생활을 유지하시길 바랍니다.
#
# --- 페르소나 2 추천 결과 ---
# 이혜성씨에게는 현재 소득이 일정하고 자차를 보유하고 있으므로 현대카드 The CLASSIC 신용카드를 추천드립니다. 이 카드는 소득이 일정한 직장인들을 위한 카드로, 혜성씨의 소득 수준에 적합한 카드입니다. 또한 자차를 보유하고 계신 점에서 주유할 때 적립되는 포인트와 할인 혜택도 매력적일 것입니다.
#
# 또한, 혜성씨가 주식 투자에 관심이 많다고 하니, 현대카드 The CLASSIC 신용카드의 포인트를 주식으로 환급하는 기능을 활용하여 주식 투자에 도움을 받을 수도 있을 것입니다.
#
# 또한, 혜성씨가 필라테스와 영화감상을 취미로 즐기고 개인 블로그와 인스타그램을 운영하고 계신다면, 현대카드 The CLASSIC 신용카드의 문화/온라인 쇼핑 관련 혜택을 활용하여 더 다양한 활동을 즐길 수 있을 것입니다.
#
# 또한, 혜성씨가 서울에 거주하고 있는 점을 고려하여 현대카드 The CLASSIC 신용카드의 서울시내 대중교통 이용 시 할인 혜택도 활용할 수 있을 것입니다.
#
# 종합적으로, 혜성씨의 프로필을 고려하여 현대카드 The CLASSIC 신용카드를 추천드리며, 다양한 혜택을 활용하여 더 풍성한 일상을 즐기시길 바랍니다.
#
# --- 페르소나 3 추천 결과 ---
# 위의 정보를 바탕으로 추천하는 최적의 카드는 현대카드 The CLASSIC 신용카드와 삼성카드 The PLATINUM 체크카드입니다.
#
# 1. 현대카드 The CLASSIC 신용카드
# - 현대카드는 국내 1위 자동차기업과의 제휴를 통해 다양한 혜택을 제공합니다.
# - 부장급 직급에 맞는 VIP 서비스와 혜택을 제공하여 업무 및 일상 생활에 편의를 더해줍니다.
# - 골프와 등산을 취미로 삼고 계신다면, 현대카드의 골프 및 레저 관련 혜택을 활용할 수 있습니다.
# - 맛집 공유 인스타그램을 운영하고 계신다면, 현대카드의 다양한 할인 혜택을 활용하여 맛집 투어를 더욱 즐길 수 있습니다.
#
# 2. 삼성카드 The PLATINUM 체크카드
# - 삼성카드는 국내에서 가장 널리 사용되는 카드 중 하나로, 현대카드와 함께 다양한 혜택을 제공합니다.
# - 40평 아파트와 고급 외제차, 국산 중형 승용차를 보유하고 계신다면, 삼성카드의 주유 및 자동차 관련 혜택을 활용할 수 있습니다.
# - 수입이 월 900~1000만원 정도이므로, 삼성카드의 다양한 혜택을 통해 신용카드 사용으로 적립된 포인트를 현금처럼 사용할 수 있습니다.
# - 정년퇴직과 자녀들과의 거리가 고민이라면, 삼성카드의 가족카드 서비스를 통해 가족들과의 소통을 더욱 강화할 수 있습니다.
#
# 이러한 이유로 현대카드 The CLASSIC 신용카드와 삼성카드 The PLATINUM 체크카드를 추천드립니다.

# %%
# # gpt-4o의 응답을 json 파일로 저장
# # 페르소나 정의
# persona1 = """이름: 김지훈 (21세, 남)
# 직업/상황: 서울 소재 4년제 대학교 2학년 재학 중
# 소득 수준: 아르바이트로 월 30~50만 원 수입, 부모님 지원 일부
# 소비 패턴:
# - 교통비 (대중교통, 택시)
# - 커피/편의점/패스트푸드 소비 빈번
# - 온라인 쇼핑 (배달앱, 쿠팡 등)
# - 휴대폰 요금 자동 이체
# 주요 관심사: 연회비 없는 카드, 할인/캐시백 혜택, 교통비 할인, 영화/문화생활 할인
# 필요한 카드 혜택:
# - 교통카드 기능 탑재 및 대중교통 할인
# - 편의점, 커피 전문점 할인
# - 휴대폰 요금 자동이체 할인
# - 온라인 쇼핑몰/배달앱 할인"""

# persona2 = """이름: 이수민 (27세, 여)
# 직업/상황: 중견기업 입사 1년 차, 마케팅 부서 근무
# 소득 수준: 월 급여 약 250~300만 원
# 소비 패턴:
# - 출퇴근 교통비, 점심/저녁 식사비
# - 스타벅스/카페 이용 빈번
# - 쇼핑 (패션, 뷰티 관련 지출)
# - 여행 및 취미 생활 (헬스, 필라테스)
# 주요 관심사: 포인트 적립, 주요 프랜차이즈 할인, 해외 결제 수수료 면제
# 필요한 카드 혜택:
# - 교통비 할인 및 자동차 관련 혜택 (렌터카, 주유)
# - 커피 전문점/레스토랑 할인
# - 온라인/백화점 쇼핑몰 할인 (쿠팡, 무신사 등)
# - 항공 마일리지 적립 또는 해외 사용 혜택
# - 무이자 할부 서비스"""

# persona3 = """이름: 박준호 (45세, 남)
# 직업/상황: IT 기업 부장, 15년 경력
# 소득 수준: 연봉 약 1억 원 이상 (월 800~900만 원)
# 소비 패턴:
# - 가족 중심 소비 (자녀 교육비, 생활비)
# - 골프/헬스 등 레저 활동 지출
# - 출장/해외 여행 빈번
# - 자동차 유지비 (주유, 보험)
# 주요 관심사: 프리미엄 혜택 (공항 라운지, VIP 서비스), 고급 레스토랑 할인, 마일리지 적립
# 필요한 카드 혜택:
# - 공항 라운지 이용 및 여행자 보험
# - 주유소 할인 및 자동차 관련 혜택
# - 프리미엄 쇼핑 혜택 (백화점, 면세점)
# - 자녀 교육비 할인 및 보험료 자동이체 혜택
# - 마일리지 적립 카드 (해외 출장이 많은 경우)
# - 헬스/골프 등 레저 할인 혜택"""

# # 페르소나 리스트로 저장
# personas = [persona1, persona2, persona3]

# def recommend_card(persona):
#     """
#     OpenAI API를 사용하여 페르소나에 맞는 카드 추천을 요청하는 함수
#     """
#     prompt = f"당신은{persona}\n위와 같은 사람입니다. 본인에게 맞는 최적의 신용 및 체크카드를 추천해주세요. 추천 이유도 함께 설명해주세요."

#     try:
#         response = client.chat.completions.create(
#             model="gpt-4o",
#             messages=[{'role': 'user', 'content': prompt}],
#             max_tokens=1000,
#             temperature=0
#         )
#         return response.choices[0].message.content.strip()
    
#     except Exception as e:
#         return f"API 호출 중 오류 발생: {e}"

# # 추천 결과 저장할 리스트 초기화
# recommendations = []

# # 각 페르소나에 대한 카드 추천 결과 출력 및 저장
# for i, persona in enumerate(personas, 1):
#     print(f"\n--- 페르소나 {i} 추천 결과 ---")
#     recommendation = recommend_card(persona)
#     print(recommendation)
    
#     # 결과를 딕셔너리로 저장
#     recommendations.append({
#         'persona_number': i,
#         'persona_description': persona,
#         'recommendation': recommendation
#     })

# # 결과를 JSON 파일로 저장
# with open('gpt-4o_recommendations.json', 'w', encoding='utf-8') as json_file:
#     json.dump(recommendations, json_file, ensure_ascii=False, indent=4)

# print("\n카드 추천 결과가 'gpt-4o_recommendations.json' 파일로 저장되었습니다.")

# %%
persona1 = """
김형석 28세 남성
데이터 분석가를 꿈꾸는 취업준비생이다.
금융 도메인에 관심이 많다.
서울 거주중 부모님과 함께 산다.
수입은 파트 타임을 뛰면서 한달에 약 30~50만원에 정도 번다.
식사는 주로 집에서 해결한다.
차는 없고 대중교통을 주로 이용한다.
평소 카페에서 자격증 공부와 취업준비를 하고 있다.
취미는 클래식 음악 감상이다.
현재 불확실한 미래에 대해 고민이 많다.
"""

persona2 = """
이혜성 30세 여성
중견기업 입사 3년 차, 마케팅 부서 근무중이다.
서울 거주중이고 보증금 500만원 월세 50 만원의 방에서 자취한다. 
소득은 약 월 250~300만원 이다.
자차를 보유중이다.
취미로는 필라테스와 영화감상이 있다.
최근 주식 투자에 관심이 많다.
개인 일상 공유 블로그와 인스타그램을 운영중이다.
"""

persona3 = """
양호성 50세 남성
국내 1위 자동차기업에 다니며 직급은 부장이다.
지방광역시에 거주하며 40평 아파트와 고급 외제차 1대와 국산 중형 승용차 1대를 보유중이다.
수입은 약 월 900~1000만원 정도이다.
가부장적인 가장으로서 아내와 슬하에 딸 2명이 있다.
고민 사항으로 다가오는 정년퇴직과 점점 멀어지고 있는 자녀들과의 심리적 거리가 있다.
취미는 등산과 골프다.
비밀리에 맛집 공유 인스타그램을 운영중이며 20만 팔로워를 보유하고 있다.
"""

# %%
exemple1 = "김지훈 씨의 소비 패턴과 필요 혜택을 고려할 때, 다음과 같은 신용 및 체크카드를 추천드립니다.\n\n1. **신한카드 YOLO Tasty** (신용카드)\n   - **이유**: 이 카드는 대중교통 할인, 편의점 및 커피 전문점 할인, 그리고 배달앱 할인 혜택을 제공합니다. 또한, 연회비가 낮아 학생에게 부담이 적습니다. 다양한 생활 밀착형 혜택이 있어 김지훈 씨의 소비 패턴에 잘 맞습니다.\n\n2. **KB국민 청춘대로 톡톡 체크카드**\n   - **이유**: 이 체크카드는 대중교통 할인, 편의점 및 커피 전문점 할인, 그리고 통신비 자동이체 시 할인 혜택을 제공합니다. 연회비가 없고, 체크카드이기 때문에 신용카드 사용이 부담스러운 경우 적합합니다.\n\n3. **우리카드 D2 체크카드**\n   - **이유**: 이 카드는 대중교통 할인, 편의점 할인, 그리고 온라인 쇼핑몰 할인 혜택을 제공합니다. 특히, 배달앱 사용 시에도 할인이 적용되어 김지훈 씨의 소비 패턴에 잘 맞습니다.\n\n이 카드들은 김지훈 씨의 주요 소비 영역에서 혜택을 제공하며, 연회비가 없거나 낮아 학생에게 적합합니다. 각 카드의 세부 혜택과 조건을 비교하여 본인에게 가장 적합한 카드를 선택하는 것이 좋습니다. 또한, 카드 사용 시에는 항상 소비를 계획적으로 하여 신용 관리를 철저히 하는 것이 중요합니다."
exemple2 = "이수민 씨의 소비 패턴과 필요 혜택을 고려하여 몇 가지 신용 및 체크카드를 추천드리겠습니다.\n\n1. **신한카드 Deep Dream**:\n   - **이유**: 이 카드는 다양한 생활 영역에서 포인트 적립이 가능하며, 특히 커피 전문점, 대형마트, 온라인 쇼핑몰에서 높은 적립률을 제공합니다. 또한, 교통비 할인 혜택도 포함되어 있어 출퇴근 시 유용합니다.\n\n2. **삼성카드 taptap O**:\n   - **이유**: 커피 전문점과 레스토랑에서 할인 혜택이 있으며, 온라인 쇼핑몰에서도 할인 혜택을 제공합니다. 또한, 해외 결제 시 수수료 면제 혜택이 있어 해외 사용 시 유리합니다.\n\n3. **현대카드 ZERO**:\n   - **이유**: 무이자 할부 서비스가 제공되며, 모든 가맹점에서 기본 할인 혜택이 있습니다. 또한, 주유소 할인 혜택도 포함되어 있어 자동차 관련 지출에 유리합니다.\n\n4. **KB국민카드 탄탄대로 Miz&Mr 티타늄**:\n   - **이유**: 항공 마일리지 적립이 가능하며, 커피 전문점, 쇼핑몰, 주유소 등에서 할인 혜택을 제공합니다. 해외 결제 시에도 혜택이 있어 여행 시 유용합니다.\n\n5. **우리카드 DA@카드의정석**:\n   - **이유**: 온라인 쇼핑몰 할인과 커피 전문점 할인 혜택이 있으며, 교통비 할인도 가능합니다. 또한, 해외 결제 시 수수료 면제 혜택이 있어 해외 여행 시 유리합니다.\n\n이 카드들은 이수민 씨의 소비 패턴과 필요 혜택에 맞춰 다양한 할인과 적립 혜택을 제공하므로, 본인의 소비 습관에 가장 잘 맞는 카드를 선택하시면 좋겠습니다. 각 카드의 세부 혜택과 연회비를 비교하여 최적의 선택을 하시기 바랍니다."
exemple3 = "박준호 씨의 소비 패턴과 필요 혜택을 고려하여 몇 가지 신용카드와 체크카드를 추천드리겠습니다. 각 카드의 주요 혜택과 이유를 함께 설명드리겠습니다.\n\n1. **신한 The CLASSIC+ 카드**\n   - **공항 라운지 이용 및 여행자 보험**: 국내외 공항 라운지 무료 이용과 여행자 보험 혜택이 제공됩니다.\n   - **주유소 할인**: 주요 주유소에서 리터당 할인 혜택이 있습니다.\n   - **프리미엄 쇼핑 혜택**: 백화점 및 면세점에서 할인 혜택을 받을 수 있습니다.\n   - **마일리지 적립**: 항공사 마일리지 적립이 가능하여 해외 출장 시 유용합니다.\n   - **추천 이유**: 다양한 프리미엄 혜택과 마일리지 적립이 가능하여 박준호 씨의 출장 및 레저 활동에 적합합니다.\n\n2. **삼성카드 S Premier**\n   - **공항 라운지 및 여행자 보험**: 국내외 공항 라운지 이용과 여행자 보험이 포함됩니다.\n   - **자동차 관련 혜택**: 주유 할인 및 자동차 보험료 할인 혜택이 있습니다.\n   - **자녀 교육비 할인**: 교육비 자동이체 시 할인 혜택이 제공됩니다.\n   - **추천 이유**: 가족 중심의 소비 패턴과 자동차 유지비 절감에 도움이 됩니다.\n\n3. **현대카드 M3 Edition2**\n   - **마일리지 적립**: 다양한 항공사 마일리지 적립이 가능하여 해외 출장 시 유리합니다.\n   - **헬스/골프 할인**: 헬스장 및 골프장 이용 시 할인 혜택이 제공됩니다.\n   - **프리미엄 쇼핑 혜택**: 백화점 및 면세점 할인 혜택이 있습니다.\n   - **추천 이유**: 레저 활동과 쇼핑 혜택이 강화되어 있어 박준호 씨의 라이프스타일에 적합합니다.\n\n4. **KB국민카드 The Prestige**\n   - **공항 라운지 및 여행자 보험**: 국내외 공항 라운지 이용과 여행자 보험 혜택이 포함됩니다.\n   - **프리미엄 쇼핑 및 레저 혜택**: 백화점, 면세점, 골프장 등에서 다양한 할인 혜택이 제공됩니다.\n   - **주유소 할인**: 주요 주유소에서 할인 혜택이 있습니다.\n   - **추천 이유**: 전반적인 프리미엄 혜택과 주유 할인으로 박준호 씨의 다양한 소비 패턴을 충족시킵니다.\n\n이 카드들은 박준호 씨의 다양한 필요를 충족시킬 수 있는 혜택을 제공하며, 각 카드의 세부 혜택과 연회비를 비교하여 최적의 선택을 하시길 바랍니다."

# %%
prompt = f"""당신은 한국 최고의 신용 및 체크 카드 전문가입니다.
            {persona1}의 성향과 니즈를 바탕으로 최적의 신용카드와 체크카드를 각각 1개씩 추천해주세요. 
            각 카드의 혜택과 추천 이유를 상세하게 설명해주세요. 가능한 한 구체적이고 유용한 정보를 제공해 주시면 좋겠습니다.
            아래는 카드 추천 예시입니다. 
            {exemple1},
            {exemple2},
            {exemple3}

            이 예시들을 참고하시되 항상 더 좋은 방안은 무엇인지 고려하며 당신의 고객이 누구고 어떠한 사람인지지 다시 되세기면서 추천 카드를 제시해주세요.
            반드시 한국어로 응답하세요.
            """
completion = client.chat.completions.create(
            model="gpt-3.5-turbo",  # GPT-3 모델 사용 (필요시 최신 모델로 변경 가능)
            messages = [{'role':'user', 'content':prompt}],
            max_tokens=1000,  # 응답의 길이 조정
            temperature=0 # 창의성 조절 (0~1 사이 값)
            )

print(completion.choices[0].message.content)
# Out:
# 김형석 씨의 경우, 수입이 한 달에 약 30~50만원 정도이고 대중교통을 주로 이용하며 집에서 식사를 해결하는 등 소비 패턴을 고려할 때, 다음과 같은 카드를 추천해드립니다.
#
# 1. **신한카드 YOLO Tasty** (신용카드)
#    - **이유**: 이 카드는 대중교통 할인, 편의점 및 커피 전문점 할인, 그리고 배달앱 할인 혜택을 제공합니다. 연회비가 낮고 학생에게 부담이 적으며, 다양한 생활 밀착형 혜택이 있어 김형석 씨의 소비 패턴에 잘 맞습니다.
#
# 2. **KB국민 청춘대로 톡톡 체크카드**
#    - **이유**: 이 체크카드는 대중교통 할인, 편의점 및 커피 전문점 할인, 그리고 통신비 자동이체 시 할인 혜택을 제공합니다. 연회비가 없고, 신용카드 사용이 부담스러운 경우에 적합합니다.
#
# 이 두 가지 카드는 김형석 씨의 주요 소비 영역에서 혜택을 제공하며, 연회비가 낮거나 없어 학생에게 적합합니다. 또한, 각 카드의 세부 혜택과 조건을 비교하여 본인에게 가장 적합한 카드를 선택하는 것이 좋습니다. 또한, 항상 소비를 계획적으로 하여 신용 관리를 철저히 하는 것이 중요합니다.

# %%
prompt = f"""당신은 한국 최고의 신용 및 체크 카드 전문가입니다.
            {persona2}의 성향과 니즈를 바탕으로 최적의 신용카드와 체크카드를 각각 1개씩 추천해주세요. 
            각 카드의 혜택과 추천 이유를 상세하게 설명해주세요. 가능한 한 구체적이고 유용한 정보를 제공해 주시면 좋겠습니다.
            아래는 카드 추천 예시입니다. 
            {exemple1},
            {exemple2},
            {exemple3}

            이 예시들을 참고하시되 항상 더 좋은 방안은 무엇인지 고려하며 당신의 고객이 누구고 어떠한 사람인지지 다시 되세기면서 추천 카드를 제시해주세요.
            반드시 한국어로 응답하세요.
            """
completion = client.chat.completions.create(
            model="gpt-3.5-turbo",  # GPT-3 모델 사용 (필요시 최신 모델로 변경 가능)
            messages = [{'role':'user', 'content':prompt}],
            max_tokens=1000,  # 응답의 길이 조정
            temperature=0 # 창의성 조절 (0~1 사이 값)
            )

print(completion.choices[0].message.content)
# Out:
# 이혜성 씨의 경우, 다음과 같은 신용카드와 체크카드를 추천해드립니다.
#
# 1. **신한카드 The CLASSIC+** (신용카드)
#    - **이유**: 이 카드는 국내외 공항 라운지 이용 및 여행자 보험 혜택을 제공합니다. 또한, 주유소 할인과 프리미엄 쇼핑 혜택이 있어 다양한 생활 영역에서 혜택을 누릴 수 있습니다. 마일리지 적립도 가능하여 여행에 유용합니다.
#
# 2. **KB국민 청춘대로 톡톡 체크카드**
#    - **이유**: 이 체크카드는 대중교통 할인, 편의점 및 커피 전문점 할인, 그리고 통신비 자동이체 시 할인 혜택을 제공합니다. 연회비가 없고, 체크카드이기 때문에 신용카드 사용이 부담스러운 경우 적합합니다.
#
# 이 카드들은 이혜성 씨의 다양한 소비 패턴과 취향을 고려하여 선택한 것입니다. 신용카드와 체크카드를 조합하여 다양한 혜택을 누리며 소비를 계획적으로 관리할 수 있을 것입니다. 또한, 각 카드의 세부 혜택과 조건을 자세히 살펴보시고 최적의 선택을 하시기 바랍니다.

# %%
prompt = f"""당신은 한국 최고의 신용 및 체크 카드 전문가입니다.
            {persona3}의 성향과 니즈를 바탕으로 최적의 신용카드와 체크카드를 각각 1개씩 추천해주세요. 
            각 카드의 혜택과 추천 이유를 상세하게 설명해주세요. 가능한 한 구체적이고 유용한 정보를 제공해 주시면 좋겠습니다.
            아래는 카드 추천 예시입니다. 
            {exemple1},
            {exemple3},
            {exemple2}

            이 예시들을 참고하시되 항상 더 좋은 방안은 무엇인지 고려하며 당신의 고객이 누구고 어떠한 사람인지 다시 되세기면서 추천 카드를 제시해주세요.
            반드시 한국어로 응답하세요.
            """
completion = client.chat.completions.create(
            model="gpt-3.5-turbo",  # GPT-3 모델 사용 (필요시 최신 모델로 변경 가능)
            messages = [{'role':'user', 'content':prompt}],
            max_tokens=1000,  # 응답의 길이 조정
            temperature=0 # 창의성 조절 (0~1 사이 값)
            )

print(completion.choices[0].message.content)
# Out:
# 고객님의 경우, 국내 최고 자동차 기업에 다니시는 부장으로서 안정적인 소득을 가지고 계시며, 가족과 함께 풍요로운 삶을 즐기시는 것으로 보입니다. 또한, 취미로 등산과 골프를 즐기시고 맛집 공유 인스타그램을 운영하며 많은 팔로워를 보유하고 계십니다.
#
# 이에 맞게 추천드리는 카드는 다음과 같습니다:
#
# 1. **신한카드 The CLASSIC+** (신용카드)
#    - **이유**: 이 카드는 공항 라운지 이용 및 여행자 보험 혜택을 제공하여 국내외 출장 및 레저 여행 시 편리합니다. 또한, 주유소 할인 및 프리미엄 쇼핑 혜택이 있어 자동차 유지비 및 쇼핑 비용을 절감할 수 있습니다. 더불어, 마일리지 적립이 가능하여 해외 출장 시에도 유용합니다.
#
# 2. **KB국민 청춘대로 톡톡 체크카드**
#    - **이유**: 이 체크카드는 대중교통 할인 및 편의점, 커피 전문점 할인 혜택을 제공하여 일상 소비를 저렴하게 할 수 있습니다. 또한, 통신비 자동이체 시 할인 혜택이 있어 가정 경제를 지원합니다. 연회비가 없어 부담이 적은 것도 장점입니다.
#
# 이 두 가지 카드는 고객님의 다양한 소비 패턴과 취미, 가족 여행 등을 고려하여 추천드리는 카드입니다. 각 카드의 혜택과 조건을 자세히 살펴보시고, 고객님의 라이프스타일에 가장 잘 맞는 카드를 선택하시기 바랍니다. 또한, 항상 소비를 계획적으로 하여 신용 관리에 유의하시는 것이 좋습니다.

# %%
# def recommend_card(persona):
#     """
#     OpenAI API를 사용하여 페르소나에 맞는 카드 추천을 요청하는 함수
#     """
#     prompt = f"""당신은 한국 최고의 신용 및 체크 카드 전문가입니다.
#             {personas}의 성향과 니즈를 바탕으로 최적의 신용카드와 체크카드를 각각 1개씩 추천해주세요. 
#             각 카드의 혜택과 추천 이유를 상세하게 설명해주세요. 가능한 한 구체적이고 유용한 정보를 제공해 주시면 좋겠습니다.
#             아래는 카드 추천 예시입니다. 
#             {exemple1},
#             {exemple2},
#             {exemple3}

#             이 예시들을 참고하시되 항상 더 좋은 방안은 무엇인지 고려하며 당신의 고객이 누구고 어떠한 사람인지지 다시 되세기면서 추천 카드를 제시해주세요.
#             반드시 한국어로 응답하세요.
#             """

#     try:
#         response = client.chat.completions.create(
#             model="gpt-3.5-turbo",  # GPT-3 모델 사용 (필요시 최신 모델로 변경 가능)
#             messages = [{'role':'user', 'content':prompt}],
#             max_tokens=1000,  # 응답의 길이 조정
#             temperature=0 # 창의성 조절 (0~1 사이 값)
#         )
#         return response.choices[0].message.content
    
#     except Exception as e:
#         return f"API 호출 중 오류 발생: {e}"

# # 각 페르소나에 대한 카드 추천 결과 출력
# for i, persona in enumerate(personas, 1):
#     print(f"\n--- 페르소나 {i} 추천 결과 ---")
#     recommendation = recommend_card(persona)
#     print(recommendation)
# Out:
# --- 페르소나 1 추천 결과 ---
# 박준호 씨의 경우, 고급 외제차와 국산 중형 승용차를 보유하고 계신 점을 고려하여 자동차 관련 혜택이 있는 카드를 추천드리겠습니다.
#
# 1. **신한카드 The CLASSIC+ 카드**
#    - **주유소 할인**: 다양한 주유소에서 할인 혜택을 받을 수 있습니다.
#    - **자동차 보험료 할인**: 자동차 보험료 결제 시 할인 혜택이 제공됩니다.
#    - **프리미엄 쇼핑 혜택**: 백화점 및 면세점에서 할인 혜택을 받을 수 있습니다.
#    - **마일리지 적립**: 해외 출장 시 항공사 마일리지 적립이 가능합니다.
#    - **추천 이유**: 자동차 관련 혜택이 강화되어 있어 박준호 씨의 자동차 유지비를 절감할 수 있습니다.
#
# 2. **삼성카드 S Premier**
#    - **주유소 할인**: 다양한 주유소에서 할인 혜택을 받을 수 있습니다.
#    - **자동차 보험료 할인**: 자동차 보험료 결제 시 할인 혜택이 제공됩니다.
#    - **자녀 교육비 할인**: 교육비 자동이체 시 할인 혜택이 있습니다.
#    - **추천 이유**: 자동차 관련 혜택과 교육비 할인 혜택이 있어 박준호 씨의 가족 중심 소비에 적합합니다.
#
# 3. **KB국민카드 The Prestige**
#    - **주유소 할인**: 다양한 주유소에서 할인 혜택을 받을 수 있습니다.
#    - **자동차 보험료 할인**: 자동차 보험료 결제 시 할인 혜택이 제공됩니다.
#    - **프리미엄 쇼핑 및 레저 혜택**: 백화점, 면세점, 골프장 등에서 다양한 할인 혜택이 제공됩니다.
#    - **추천 이유**: 주유소 할인 및 프리미엄 쇼핑 혜택이 있어 박준호 씨의 다양한 소비 패턴을 충족시킵니다.
#
# 이 세 가지 카드는 박준호 씨의 자동차 관련 소비에 유용한 혜택을 제공하며, 각 카드의 세부 혜택과 연회비를 비교하여 가장 적합한 카드를 선택하시기 바랍니다. 또한, 자동차 관련 소비 외에도 다른 소비 패턴을 고려하여 최적의 선택을 하시길 권장드립니다.
#
# --- 페르소나 2 추천 결과 ---
# 박준호 씨의 경우, 고급 외제차와 국산 중형 승용차를 보유하고 계신 점을 고려하여 다음과 같은 카드를 추천해드립니다.
#
# 1. **신한카드 The CLASSIC+ 카드** (신용카드)
#    - **이유**: 이 카드는 공항 라운지 이용 및 여행자 보험 혜택을 제공하여 해외 출장 시 편리합니다. 또한, 주유소 할인과 프리미엄 쇼핑 혜택이 있어 고급 외제차 관련 지출에 유용합니다. 마일리지 적립도 가능하여 해외 출장 시에도 혜택을 누릴 수 있습니다.
#
# 2. **삼성카드 S Premier** (체크카드)
#    - **이유**: 이 체크카드는 공항 라운지 이용 및 여행자 보험 혜택을 제공하여 해외 여행 시 편리합니다. 주유 할인과 자동차 보험료 할인 혜택이 있어 자동차 관련 지출을 절감할 수 있습니다. 또한, 자녀 교육비 할인 혜택도 제공되어 가족 중심의 소비에 적합합니다.
#
# 이 두 가지 카드는 박준호 씨의 고급 외제차와 국산 중형 승용차 관련 지출을 고려하여 선택한 추천 카드입니다. 각 카드의 혜택과 조건을 자세히 살펴보시고, 본인의 소비 습관과 필요에 맞는 카드를 선택하시기 바랍니다. 또한, 연회비와 기타 부가 혜택도 함께 고려하여 최적의 선택을 하시길 바랍니다.
#
# --- 페르소나 3 추천 결과 ---
# 박준호 씨의 경우, 다양한 프리미엄 혜택과 주유 할인이 있는 카드를 추천드립니다.
#
# 1. **신한 The CLASSIC+ 카드**
#    - **혜택**: 공항 라운지 이용, 주유소 할인, 프리미엄 쇼핑 혜택, 마일리지 적립
#    - **추천 이유**: 출장 및 레저 활동에 적합한 다양한 혜택이 제공되며, 프리미엄 쇼핑 혜택과 마일리지 적립으로 다양한 혜택을 누릴 수 있습니다.
#
# 2. **KB국민카드 The Prestige**
#    - **혜택**: 공항 라운지 이용, 프리미엄 쇼핑 및 레저 혜택, 주유소 할인
#    - **추천 이유**: 프리미엄 혜택과 주유 할인이 강조되어 있어 다양한 소비 패턴을 충족시킬 수 있습니다.
#
# 이 두 가지 카드는 박준호 씨의 다양한 필요를 고려하여 선택한 것으로, 각 카드의 세부 혜택과 연회비를 비교하여 최적의 선택을 하시기 바랍니다. 또한, 카드 사용 시에는 항상 신용 관리를 철저히 하여 소비를 계획적으로 하는 것이 중요합니다.
